# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the dataset

# %%
data =pd.read_csv('nepal_rental_kathmandu_dataset.csv')
data.head()
# Out:
#    listing_id                                              title  \
# 0        9541                                     House for rent
# 1        9464   House on rent: Civil Homes Phase VII, Nagarjun-6
# 2        9361  4 BHK Semi Furnished House for Rent at Bhaisepati
# 3        9087  House on Rent at Koteswor for Office or Restau...
# 4        9034    Fully-Furnished House on rent at Budhanilkantha
#
#    monthly_rent_npr  area_sqft_approx  road_width_ft  \
# 0           75000.0           1197.88           14.0
# 1           50000.0           1026.75           10.0
# 2          119999.0           1540.12           12.0
# 3          250000.0           3935.88           26.0
# 4          120000.0           1369.00           13.0
#
#                                             location  ward  \
# 0  Samakhusi 26 Kathmandu Metropolis Kathmandu, B...  26.0
# 1  Sitapaila 6 Kathmandu Metropolis Kathmandu, Ba...   6.0
# 2  Bhaisepati 18 Kathmandu Metropolis Kathmandu, ...  18.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   listing_id        156 non-null    int64
#  1   title             156 non-null    str
#  2   monthly_rent_npr  156 non-null    float64
#  3   area_sqft_approx  117 non-null    float64
#  4   road_width_ft     128 non-null    float64
#  5   location          156 non-null    str
#  6   ward              81 non-null     float64
#  7   municipality      94 non-null     str
#  8   district          156 non-null    str
#  9   property_type     156 non-null    str
#  10  house_type        118 non-null    str
#  11  direction         156 non-null    str
#  12  bedrooms          148 non-null    float64
#  13  bathrooms         153 non-null    float64
#  14  living_rooms      89 non-null     float64
#  15  kitchens          121 non-null    float64
#  16  total_rooms       30 non-null     float64
# ...

# %%
data.drop(columns=["listing_id", "source", "district"], inplace=True)

# %%
data.head()
# Out:
#                                                title  monthly_rent_npr  \
# 0                                     House for rent           75000.0
# 1   House on rent: Civil Homes Phase VII, Nagarjun-6           50000.0
# 2  4 BHK Semi Furnished House for Rent at Bhaisepati          119999.0
# 3  House on Rent at Koteswor for Office or Restau...          250000.0
# 4    Fully-Furnished House on rent at Budhanilkantha          120000.0
#
#    area_sqft_approx  road_width_ft  \
# 0           1197.88           14.0
# 1           1026.75           10.0
# 2           1540.12           12.0
# 3           3935.88           26.0
# 4           1369.00           13.0
#
#                                             location  ward  \
# 0  Samakhusi 26 Kathmandu Metropolis Kathmandu, B...  26.0
# 1  Sitapaila 6 Kathmandu Metropolis Kathmandu, Ba...   6.0
# 2  Bhaisepati 18 Kathmandu Metropolis Kathmandu, ...  18.0
# 3  Koteswor 32 Kathmandu Metropolis Kathmandu, Ba...  32.0
# ...

# %%
for cols in data.columns:
    print(f"{cols:22s} -> {data[cols].nunique()} unique values")
# Out:
# title                  -> 156 unique values
# monthly_rent_npr       -> 66 unique values
# area_sqft_approx       -> 37 unique values
# road_width_ft          -> 18 unique values
# location               -> 125 unique values
# ward                   -> 20 unique values
# municipality           -> 36 unique values
# property_type          -> 3 unique values
# house_type             -> 8 unique values
# direction              -> 11 unique values
# bedrooms               -> 12 unique values
# bathrooms              -> 10 unique values
# living_rooms           -> 10 unique values
# kitchens               -> 5 unique values
# total_rooms            -> 11 unique values
# parking                -> 11 unique values
# built_up_sqft          -> 23 unique values
# no_of_flats            -> 10 unique values
# built_year             -> 19 unique values
# description            -> 143 unique values
# city                   -> 3 unique values

# %%
missing = (data.isnull().sum() / len(data) * 100).round(1).sort_values(ascending=False)
missing = missing[missing > 0]
print(missing)

plt.figure(figsize=(8, 6))
missing.plot(kind="barh")
plt.xlabel("% missing")
plt.title("Missing Values by Column")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# built_up_sqft       81.4
# total_rooms         80.8
# ward                48.1
# living_rooms        42.9
# municipality        39.7
# area_sqft_approx    25.0
# house_type          24.4
# kitchens            22.4
# no_of_flats         21.8
# road_width_ft       17.9
# parking             14.7
# description          7.7
# bedrooms             5.1
# bathrooms            1.9
# dtype: float64
